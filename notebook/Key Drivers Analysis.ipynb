# %% [markdown]
# # Key Drivers Analysis with Kano model and Shapley values

# %% [markdown]
# The Kano Model is an approach to prioritize attributes on a product based on the degree to which they are likely to satisfy customers.
#
# The Shapley value is a concept from game theory that quantifies how much each player contributes to the game outcome. The concept, however, can be used in a wide variety of decomposition problems. The algorithm for the Shapley value decomposition is always the same – it is just the value function that varies.
#
# We use Kano theory and Shapley value to identify key drivers of overall satisfaction and/or dissatisfaction.

# %% [markdown]
# #### Install the python package

# %%
# !pip3 uninstall --yes shapleykano
# !pip3 install --upgrade ../dist/shapleykano-1.0.0.tar.gz
# Out:
# Uninstalling shapleykano-1.0.0:
#   Successfully uninstalled shapleykano-1.0.0
# Processing /home/jupyter/shapleykano/dist/shapleykano-1.0.0.tar.gz
# Building wheels for collected packages: shapleykano
#   Running setup.py bdist_wheel for shapleykano ... done
#   Stored in directory: /home/jupyter/.cache/pip/wheels/4b/45/ef/19b21ed4c3035047ea6d787cab6c2b9d641b44a99c9e714d21
# Successfully built shapleykano
# Installing collected packages: shapleykano
# Successfully installed shapleykano-1.0.0

# %% [markdown]
# #### Load an example dataset

# %%
import pandas as pd

df = pd.read_csv('../data/example_01.csv')

y_varname = 'Overall Satisfaction'
X_varnames = df.columns.values.tolist()
X_varnames.remove(y_varname)

# %% [markdown]
# #### Key Dissatisfaction Analysis (KDA)

# %%
from shapleykano.kanomodel import KanoModel

model = KanoModel(df, 
                  y_varname, X_varnames, 
                  analysis = 'kda',
                  y_dissat_upperbound = 6, y_sat_lowerbound = 9,
                  X_dissat_upperbound = 6, X_sat_lowerbound = 9)

kda = model.key_drivers() ;kda
# Out:
# Computing Shapley values: it could take some time ...
# Number of sampled coalitions : 33984  /  1048576
#     Num     Attribute  Shapley value  Impact (%)  Impact (base 100)  \
# 0     0  Attribute 00          12.31       22.99             459.76
# 1     2  Attribute 02           9.28       17.34             346.72
# 2     1  Attribute 01           9.23       17.24             344.88
# 3    17  Attribute 17           2.98        5.56             111.22
# 4    10  Attribute 10           2.47        4.61              92.19
# 5     9  Attribute 09           2.46        4.60              92.02
# 6     4  Attribute 04           2.23        4.17              83.41
# 7    18  Attribute 18           2.03        3.79              75.82
# 8     5  Attribute 05           1.72        3.21              64.11
# 9     7  Attribute 07           1.69        3.16              63.11
# 10    3  Attribute 03           1.57        2.94              58.71
# 11   12  Attribute 12           1.54        2.88              57.69
# 12   15  Attribute 15           1.36        2.55              50.97
# 13   13  Attribute 13           0.95        1.78              35.50
# 14    6  Attribute 06           0.66        1.23              24.68
# 15   11  Attribute 11           0.54        1.00              20.07
# 16   14  Attribute 14           0.51        0.96              19.15
# 17    8  Attribute 08           0.00        0.00               0.00
# 18   16  Attribute 16           0.00        0.00               0.00
# 19   19  Attribute 19           0.00        0.00               0.00
#
#     Dissatisfied on attribute (%)  \
# 0                           13.30
# 1                           19.49
# 2                           11.07
# 3                           10.86
# 4                           12.81
# 5                           13.74
# 6                            9.99
# 7                            8.69
# 8                            5.92
# 9                            6.08
# 10                           4.23
# 11                          11.07
# 12                           6.13
# 13                          11.62
# 14                           4.78
# 15                          17.48
# 16                          14.39
# 17                          21.61
# 18                          32.41
# 19                          28.83
#
#     %(Dissatisfied on attribute | Dissatisfied Overall)  \
# 0                                               81.18
# 1                                               75.69
# 2                                               65.10
# 3                                               46.27
# 4                                               46.27
# 5                                               47.06
# 6                                               41.57
# 7                                               38.43
# 8                                               29.41
# 9                                               28.24
# 10                                              20.78
# 11                                              40.39
# 12                                              29.80
# 13                                              37.65
# 14                                              22.75
# 15                                              50.20
# 16                                              42.75
# 17                                              52.16
# 18                                              64.31
# 19                                              61.18
#
#     %(Dissatisfied on attribute | Not dissatisfied Overall)  Difference  \
# 0                                                2.33             78.84
# 1                                               10.41             65.28
# 2                                                2.33             62.76
# 3                                                5.17             41.10
# 4                                                7.44             38.83
# 5                                                8.39             38.67
# 6                                                4.92             36.65
# 7                                                3.91             34.52
# 8                                                2.15             27.27
# 9                                                2.52             25.71
# 10                                               1.58             19.21
# 11                                               6.37             34.02
# 12                                               2.33             27.47
# 13                                               7.44             30.20
# 14                                               1.89             20.85
# 15                                              12.24             37.96
# 16                                               9.84             32.90
# 17                                              16.72             35.44
# 18                                              27.32             37.00
# 19                                              23.66             37.52
#
#     Reach  Noise  Objective
# 0   81.18   2.33      78.84
# 1   90.59  11.67      78.92
# 2   92.55  12.62      79.93
# 3   93.73  15.46      78.27
# 4   94.51  19.05      75.46
# 5   94.90  21.45      73.45
# 6   95.29  23.09      72.20
# 7   95.29  23.97      71.32
# 8   95.29  24.35      70.94
# 9   95.29  24.61      70.69
# 10  95.29  25.17      70.12
# 11  95.29  26.75      68.54
# 12  95.29  27.13      68.16
# 13  95.69  29.59      66.10
# 14  95.69  29.84      65.84
# 15  96.08  33.38      62.70
# 16  96.47  36.03      60.45
# 17  96.86  39.50      57.37
# 18  98.43  48.20      50.23
# 19  98.43  49.46      48.97

# %% [markdown]
# #### Key Enhancers Analysis (KEA)

# %%
X_dissat_upperbound = 6
max_objective_idx = kda.index[kda['Objective'] == max(kda['Objective'])].tolist()
key_dissat_driver = kda.iloc[0:max_objective_idx[0]+1].Attribute.tolist()
df_without_failure_on_kda = df.loc[~(df[key_dissat_driver] <= X_dissat_upperbound).any(axis=1)]

model = KanoModel(df_without_failure_on_kda, 
                  y_varname, X_varnames, 
                  analysis = 'kea',
                  y_dissat_upperbound = 6, y_sat_lowerbound = 9,
                  X_dissat_upperbound = 6, X_sat_lowerbound = 9)

kea = model.key_drivers() ;kea
# Out:
# Computing Shapley values: it could take some time ...
# Number of sampled coalitions : 33984  /  1048576
#     Num     Attribute  Shapley value  Impact (%)  Impact (base 100)  \
# 0     0  Attribute 00           6.94       19.09             381.84
# 1     2  Attribute 02           4.21       11.59             231.86
# 2     1  Attribute 01           4.18       11.49             229.84
# 3     9  Attribute 09           2.74        7.54             150.85
# 4    10  Attribute 10           2.32        6.37             127.48
# 5     8  Attribute 08           2.03        5.59             111.75
# 6    17  Attribute 17           2.01        5.52             110.47
# 7    12  Attribute 12           1.96        5.39             107.83
# 8    18  Attribute 18           1.89        5.21             104.21
# 9    19  Attribute 19           1.57        4.32              86.31
# 10    4  Attribute 04           1.33        3.67              73.46
# 11   11  Attribute 11           1.27        3.50              69.93
# 12   14  Attribute 14           1.27        3.50              69.91
# 13   16  Attribute 16           1.08        2.98              59.53
# 14    7  Attribute 07           0.81        2.24              44.83
# 15   13  Attribute 13           0.68        1.87              37.37
# 16   15  Attribute 15           0.05        0.13               2.53
# 17    5  Attribute 05           0.00        0.00               0.00
# 18    6  Attribute 06           0.00        0.00               0.00
# 19    3  Attribute 03           0.00        0.00               0.00
#
#     Satisfied on attribute (%)  %(Satisfied on attribute | Satisfied Overall)  \
# 0                        42.56                                          90.03
# 1                        39.93                                          75.95
# 2                        50.96                                          91.07
# 3                        36.80                                          67.01
# 4                        38.29                                          67.87
# 5                        33.24                                          59.97
# 6                        42.70                                          71.99
# 7                        41.42                                          69.93
# 8                        45.77                                          74.05
# 9                        26.48                                          47.77
# 10                       42.06                                          71.31
# 11                       35.09                                          60.82
# 12                       39.57                                          67.01
# 13                       24.41                                          43.99
# 14                       51.89                                          79.55
# 15                       45.12                                          72.16
# 16                       49.75                                          75.43
# 17                       51.74                                          76.98
# 18                       57.86                                          80.58
# 19                       87.26                                          98.63
#
#     %(Satisfied on attribute | Not Satisfied Overall)  Difference   Reach  \
# 0                                                8.88       81.15   90.03
# 1                                               14.36       61.59   93.13
# 2                                               22.51       68.56   95.19
# 3                                               15.45       51.56   96.39
# 4                                               17.40       50.47   96.56
# 5                                               14.36       45.61   96.56
# 6                                               22.02       49.97   97.25
# 7                                               21.29       48.64   97.42
# 8                                               25.79       48.26   97.77
# 9                                               11.44       36.33   97.94
# 10                                              21.41       49.89   98.11
# 11                                              16.91       43.91   98.11
# 12                                              20.19       46.82   98.28
# 13                                              10.58       33.40   98.28
# 14                                              32.36       47.19   98.63
# 15                                              26.03       46.13   98.80
# 16                                              31.63       43.80   98.80
# 17                                              33.94       43.03   98.97
# 18                                              41.85       38.74   99.14
# 19                                              79.20       19.43  100.00
#
#     Noise  Objective
# 0    8.88      81.15
# 1   19.22      73.91
# 2   31.02      64.17
# 3   36.86      59.53
# 4   39.90      56.66
# 5   41.73      54.84
# 6   46.23      51.02
# 7   48.05      49.37
# 8   49.51      48.25
# 9   50.73      47.21
# 10  51.95      46.16
# 11  52.55      45.56
# 12  53.89      44.39
# 13  54.14      44.15
# 14  56.33      42.30
# 15  58.52      40.28
# 16  60.83      37.97
# 17  63.63      35.34
# 18  65.57      33.57
# 19  88.08      11.92
